# %%
# %load_ext autoreload

# %%
import lightning.pytorch as pl
import torch
import os
import dask.dataframe as dd
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import scanpy as sc
import anndata
from torch.utils.data import Dataset, DataLoader
from matplotlib import rcParams

# %%
# %autoreload 2
from self_supervision.data.datamodules import AdataDataset
from self_supervision.tester.perturbations.perturbation_clf import eval_emb_knn

# %%
DATA_PATH = '/lustre/groups/ml01/workspace/till.richter/merlin_cxg_2023_05_15_sf-log1p'  # this is a shared directory in which the data is stored
MODEL_PATH = '/lustre/groups/ml01/workspace/till.richter/trained_models/'
RESULT_PATH = '/lustre/groups/ml01/workspace/till.richter/ssl_results'
ADATA_PATH = '/lustre/groups/ml01/workspace/till.richter/'
HVG = True

# %%
model_dirs = [
    # ZERO-SHOT MODELS
    MODEL_PATH + '/pretext_models/masking/CN_Pert_MLP_50psciplex2020/default/version_0/checkpoints/best_checkpoint_val.ckpt',
    
    # SUPERVISED MODELS
    MODEL_PATH + '/final_models/perturbations/supervised_Srivatsan_2020_sciplex3_train_val_hvg_new_run0/default/version_0/checkpoints/best_checkpoint_val.ckpt',
    MODEL_PATH + '/final_models/perturbations/supervised_Srivatsan_2020_sciplex3_train_val_hvg_new_run1/default/version_0/checkpoints/best_checkpoint_val.ckpt',
    MODEL_PATH + '/final_models/perturbations/supervised_Srivatsan_2020_sciplex3_train_val_hvg_new_run2/default/version_0/checkpoints/best_checkpoint_val.ckpt',
    MODEL_PATH + '/final_models/perturbations/supervised_Srivatsan_2020_sciplex3_train_val_hvg_new_run3/default/version_0/checkpoints/best_checkpoint_val.ckpt',
    MODEL_PATH + '/final_models/perturbations/supervised_Srivatsan_2020_sciplex3_train_val_hvg_new_run4/default/version_0/checkpoints/best_checkpoint_val.ckpt',
    
    # SELF-SUPERVISED MODELS
    MODEL_PATH + '/final_models/perturbations/CN_Pert_MLP_50psciplex2020_Srivatsan_2020_sciplex3_train_val_hvg_ssl_run0/default/version_0/checkpoints/best_checkpoint_val.ckpt',
    MODEL_PATH + '/final_models/perturbations/CN_Pert_MLP_50psciplex2020_Srivatsan_2020_sciplex3_train_val_hvg_ssl_run1/default/version_0/checkpoints/best_checkpoint_val.ckpt',
    MODEL_PATH + '/final_models/perturbations/CN_Pert_MLP_50psciplex2020_Srivatsan_2020_sciplex3_train_val_hvg_ssl_run2/default/version_0/checkpoints/best_checkpoint_val.ckpt',
    MODEL_PATH + '/final_models/perturbations/CN_Pert_MLP_50psciplex2020_Srivatsan_2020_sciplex3_train_val_hvg_ssl_run3/default/version_0/checkpoints/best_checkpoint_val.ckpt',
    MODEL_PATH + '/final_models/perturbations/CN_Pert_MLP_50psciplex2020_Srivatsan_2020_sciplex3_train_val_hvg_run4/default/version_0/checkpoints/best_checkpoint_val.ckpt',
    
    
]

# %%
eval_emb_knn(model_dirs=model_dirs)
# Out:
# Loaded val labels:  (5639,) test labels:  (27185,)
# Evaluating /lustre/groups/ml01/workspace/till.richter/trained_models//pretext_models/masking/CN_Pert_MLP_50psciplex2020/default/version_0/checkpoints/best_checkpoint_val.ckpt
# Get index for pretrained
# ...
